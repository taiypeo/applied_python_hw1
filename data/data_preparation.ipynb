# %%
import pandas as pd

# %%
D_clients = pd.read_csv("https://raw.githubusercontent.com/aiedu-courses/stepik_linear_models/main/datasets/D_clients.csv")
D_close_loan = pd.read_csv("https://raw.githubusercontent.com/aiedu-courses/stepik_linear_models/main/datasets/D_close_loan.csv")
D_job = pd.read_csv("https://raw.githubusercontent.com/aiedu-courses/stepik_linear_models/main/datasets/D_job.csv")
D_last_credit = pd.read_csv("https://raw.githubusercontent.com/aiedu-courses/stepik_linear_models/main/datasets/D_last_credit.csv")
D_loan = pd.read_csv("https://raw.githubusercontent.com/aiedu-courses/stepik_linear_models/main/datasets/D_loan.csv")
D_pens = pd.read_csv("https://raw.githubusercontent.com/aiedu-courses/stepik_linear_models/main/datasets/D_pens.csv")
D_salary = pd.read_csv("https://raw.githubusercontent.com/aiedu-courses/stepik_linear_models/main/datasets/D_salary.csv")
D_target = pd.read_csv("https://raw.githubusercontent.com/aiedu-courses/stepik_linear_models/main/datasets/D_target.csv")
D_work = pd.read_csv("https://raw.githubusercontent.com/aiedu-courses/stepik_linear_models/main/datasets/D_work.csv")

# %%
df = D_clients
df.shape
# Out:
# (16000, 14)

# %%
df.isna().any()
# Out:
# ID                         False
# AGE                        False
# GENDER                     False
# EDUCATION                  False
# MARITAL_STATUS             False
# CHILD_TOTAL                False
# DEPENDANTS                 False
# SOCSTATUS_WORK_FL          False
# SOCSTATUS_PENS_FL          False
# REG_ADDRESS_PROVINCE       False
# FACT_ADDRESS_PROVINCE      False
# POSTAL_ADDRESS_PROVINCE    False
# FL_PRESENCE_FL             False
# OWN_AUTO                   False
# dtype: bool

# %%
df.describe()
# Out:
#                  ID           AGE       GENDER   CHILD_TOTAL    DEPENDANTS  \
# count  1.600000e+04  16000.000000  16000.00000  16000.000000  16000.000000
# mean   1.068124e+08     40.394750      0.65325      1.097562      0.644437
# std    4.618946e+03     11.600365      0.47595      0.995731      0.811975
# min    1.068044e+08     21.000000      0.00000      0.000000      0.000000
# 25%    1.068084e+08     30.000000      0.00000      0.000000      0.000000
# 50%    1.068124e+08     39.000000      1.00000      1.000000      0.000000
# 75%    1.068164e+08     50.000000      1.00000      2.000000      1.000000
# max    1.068204e+08     67.000000      1.00000     10.000000      7.000000
#
#        SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  FL_PRESENCE_FL      OWN_AUTO
# count       16000.000000       16000.000000    16000.000000  16000.000000
# mean            0.909375           0.134625        0.310188      0.116562
# ...

# %% [markdown]
# ## Join with D_work

# %%
df["SOCSTATUS_WORK_FL"].value_counts(dropna=False)
# Out:
# 1    14550
# 0     1450
# Name: SOCSTATUS_WORK_FL, dtype: int64

# %%
D_work
# Out:
#    ID  FLAG      COMMENT
# 0   1     0     работает
# 1   2     1  не работает
# 2   3     2  не известно

# %% [markdown]
# В описании таблицы противоположный смысл у 0 и 1. Исправим.

# %%
D_work.loc[0, "COMMENT"] = "не работает"
D_work.loc[1, "COMMENT"] = "работает"
D_work
# Out:
#    ID  FLAG      COMMENT
# 0   1     0  не работает
# 1   2     1     работает
# 2   3     2  не известно

# %%
df = df.merge(D_work["COMMENT"].rename("SOCSTATUS_WORK_FL_COMMENT"), how="left", left_on="SOCSTATUS_WORK_FL", right_on=D_work["FLAG"])
df
# Out:
#               ID  AGE  GENDER            EDUCATION      MARITAL_STATUS  \
# 0      106805103   42       1              Среднее  Не состоял в браке
# 1      106809308   28       1  Среднее специальное      Состою в браке
# 2      106805867   64       0  Среднее специальное      Состою в браке
# 3      106808779   54       1  Среднее специальное      Состою в браке
# 4      106814289   26       0  Среднее специальное      Состою в браке
# ...          ...  ...     ...                  ...                 ...
# 15995  106814680   26       1              Среднее  Не состоял в браке
# 15996  106812464   26       0  Среднее специальное      Состою в браке
# 15997  106809255   30       1  Среднее специальное  Не состоял в браке
# 15998  106814593   25       0  Среднее специальное      Состою в браке
# 15999  106813640   26       1               Высшее  Не состоял в браке
#
#        CHILD_TOTAL  DEPENDANTS  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  \
# ...

# %%
df[(df["SOCSTATUS_WORK_FL"] == 0) & (df["SOCSTATUS_WORK_FL_COMMENT"] != "не работает")]
# Out:
# Empty DataFrame
# Columns: [ID, AGE, GENDER, EDUCATION, MARITAL_STATUS, CHILD_TOTAL, DEPENDANTS, SOCSTATUS_WORK_FL, SOCSTATUS_PENS_FL, REG_ADDRESS_PROVINCE, FACT_ADDRESS_PROVINCE, POSTAL_ADDRESS_PROVINCE, FL_PRESENCE_FL, OWN_AUTO, SOCSTATUS_WORK_FL_COMMENT]
# Index: []

# %%
df[(df["SOCSTATUS_WORK_FL"] == 1) & (df["SOCSTATUS_WORK_FL_COMMENT"] == "не работает")]
# Out:
# Empty DataFrame
# Columns: [ID, AGE, GENDER, EDUCATION, MARITAL_STATUS, CHILD_TOTAL, DEPENDANTS, SOCSTATUS_WORK_FL, SOCSTATUS_PENS_FL, REG_ADDRESS_PROVINCE, FACT_ADDRESS_PROVINCE, POSTAL_ADDRESS_PROVINCE, FL_PRESENCE_FL, OWN_AUTO, SOCSTATUS_WORK_FL_COMMENT]
# Index: []

# %% [markdown]
# ## Join with D_pens

# %%
D_pens
# Out:
#    ID  FLAG       COMMENT
# 0   1     0     пенсионер
# 1   2     1  не пенсионер

# %% [markdown]
# Опять же, в описании таблицы противоположный смысл у 0 и 1. Поменяем.

# %%
D_pens.loc[0, "COMMENT"] = "не пенсионер"
D_pens.loc[1, "COMMENT"] = "пенсионер"
D_pens
# Out:
#    ID  FLAG       COMMENT
# 0   1     0  не пенсионер
# 1   2     1     пенсионер

# %%
df = df.merge(D_pens["COMMENT"].rename("SOCSTATUS_PENS_FL_COMMENT"), how="left", left_on="SOCSTATUS_PENS_FL", right_on=D_pens["FLAG"])
df
# Out:
#               ID  AGE  GENDER            EDUCATION      MARITAL_STATUS  \
# 0      106805103   42       1              Среднее  Не состоял в браке
# 1      106809308   28       1  Среднее специальное      Состою в браке
# 2      106805867   64       0  Среднее специальное      Состою в браке
# 3      106808779   54       1  Среднее специальное      Состою в браке
# 4      106814289   26       0  Среднее специальное      Состою в браке
# ...          ...  ...     ...                  ...                 ...
# 15995  106814680   26       1              Среднее  Не состоял в браке
# 15996  106812464   26       0  Среднее специальное      Состою в браке
# 15997  106809255   30       1  Среднее специальное  Не состоял в браке
# 15998  106814593   25       0  Среднее специальное      Состою в браке
# 15999  106813640   26       1               Высшее  Не состоял в браке
#
#        CHILD_TOTAL  DEPENDANTS  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  \
# ...

# %% [markdown]
# ## Join with D_agreement (D_target)

# %%
D_target
# Out:
#        AGREEMENT_RK  ID_CLIENT  TARGET
# 0          59910150  106804370       0
# 1          59910230  106804371       0
# 2          59910525  106804372       0
# 3          59910803  106804373       0
# 4          59911781  106804374       0
# ...             ...        ...     ...
# 15218      75291424  106819588       0
# 15219      75291888  106819589       0
# 15220      75291923  106819590       0
# 15221      75291960  106819591       0
# 15222      75292242  106819592       0
#
# [15223 rows x 3 columns]

# %%
D_target.isna().any()
# Out:
# AGREEMENT_RK    False
# ID_CLIENT       False
# TARGET          False
# dtype: bool

# %%
D_target.describe()
# Out:
#        AGREEMENT_RK     ID_CLIENT        TARGET
# count  1.522300e+04  1.522300e+04  15223.000000
# mean   6.540183e+07  1.068120e+08      0.119030
# std    4.568181e+06  4.394646e+03      0.323835
# min    5.991015e+07  1.068044e+08      0.000000
# 25%    6.192092e+07  1.068082e+08      0.000000
# 50%    6.437100e+07  1.068120e+08      0.000000
# 75%    6.708802e+07  1.068158e+08      0.000000
# max    7.529224e+07  1.068196e+08      1.000000

# %%
df = df.merge(D_target[["AGREEMENT_RK", "TARGET"]], how="left", left_on="ID", right_on=D_target["ID_CLIENT"])
df
# Out:
#               ID  AGE  GENDER            EDUCATION      MARITAL_STATUS  \
# 0      106805103   42       1              Среднее  Не состоял в браке
# 1      106809308   28       1  Среднее специальное      Состою в браке
# 2      106805867   64       0  Среднее специальное      Состою в браке
# 3      106808779   54       1  Среднее специальное      Состою в браке
# 4      106814289   26       0  Среднее специальное      Состою в браке
# ...          ...  ...     ...                  ...                 ...
# 15995  106814680   26       1              Среднее  Не состоял в браке
# 15996  106812464   26       0  Среднее специальное      Состою в браке
# 15997  106809255   30       1  Среднее специальное  Не состоял в браке
# 15998  106814593   25       0  Среднее специальное      Состою в браке
# 15999  106813640   26       1               Высшее  Не состоял в браке
#
#        CHILD_TOTAL  DEPENDANTS  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  \
# ...

# %%
df.isna().any()
# Out:
# ID                           False
# AGE                          False
# GENDER                       False
# EDUCATION                    False
# MARITAL_STATUS               False
# CHILD_TOTAL                  False
# DEPENDANTS                   False
# SOCSTATUS_WORK_FL            False
# SOCSTATUS_PENS_FL            False
# REG_ADDRESS_PROVINCE         False
# FACT_ADDRESS_PROVINCE        False
# POSTAL_ADDRESS_PROVINCE      False
# FL_PRESENCE_FL               False
# OWN_AUTO                     False
# SOCSTATUS_WORK_FL_COMMENT    False
# SOCSTATUS_PENS_FL_COMMENT    False
# AGREEMENT_RK                  True
# TARGET                        True
# dtype: bool

# %%
df[df["TARGET"].isna()]
# Out:
#               ID  AGE  GENDER            EDUCATION      MARITAL_STATUS  \
# 35     106820101   33       1              Среднее      Состою в браке
# 88     106819731   58       1  Среднее специальное      Состою в браке
# 93     106820056   34       1               Высшее      Состою в браке
# 119    106820194   45       0               Высшее      Состою в браке
# 126    106820112   34       1              Среднее      Состою в браке
# ...          ...  ...     ...                  ...                 ...
# 15876  106819660   64       1              Среднее  Не состоял в браке
# 15899  106819886   48       1  Среднее специальное  Не состоял в браке
# 15916  106819938   37       1  Среднее специальное         Разведен(а)
# 15945  106819995   45       1  Среднее специальное         Разведен(а)
# 15946  106819741   38       1               Высшее  Не состоял в браке
#
#        CHILD_TOTAL  DEPENDANTS  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  \
# ...

# %%
D_target[D_target["ID_CLIENT"] == 106820101]
# Out:
# Empty DataFrame
# Columns: [AGREEMENT_RK, ID_CLIENT, TARGET]
# Index: []

# %% [markdown]
# Есть 777 клиентов, для которых у нас нет информации о таргете. Уберем их.

# %%
df = df.dropna()
df
# Out:
#               ID  AGE  GENDER            EDUCATION      MARITAL_STATUS  \
# 0      106805103   42       1              Среднее  Не состоял в браке
# 1      106809308   28       1  Среднее специальное      Состою в браке
# 2      106805867   64       0  Среднее специальное      Состою в браке
# 3      106808779   54       1  Среднее специальное      Состою в браке
# 4      106814289   26       0  Среднее специальное      Состою в браке
# ...          ...  ...     ...                  ...                 ...
# 15995  106814680   26       1              Среднее  Не состоял в браке
# 15996  106812464   26       0  Среднее специальное      Состою в браке
# 15997  106809255   30       1  Среднее специальное  Не состоял в браке
# 15998  106814593   25       0  Среднее специальное      Состою в браке
# 15999  106813640   26       1               Высшее  Не состоял в браке
#
#        CHILD_TOTAL  DEPENDANTS  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  \
# ...

# %%
df.loc[:, ["AGREEMENT_RK", "TARGET"]] = df[["AGREEMENT_RK", "TARGET"]].astype(int)
# Out:
# <ipython-input-23-6468091d60d6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, ["AGREEMENT_RK", "TARGET"]] = df[["AGREEMENT_RK", "TARGET"]].astype(int)
# <ipython-input-23-6468091d60d6>:1: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, ["AGREEMENT_RK", "TARGET"]] = df[["AGREEMENT_RK", "TARGET"]].astype(int)

# %%
df
# Out:
#               ID  AGE  GENDER            EDUCATION      MARITAL_STATUS  \
# 0      106805103   42       1              Среднее  Не состоял в браке
# 1      106809308   28       1  Среднее специальное      Состою в браке
# 2      106805867   64       0  Среднее специальное      Состою в браке
# 3      106808779   54       1  Среднее специальное      Состою в браке
# 4      106814289   26       0  Среднее специальное      Состою в браке
# ...          ...  ...     ...                  ...                 ...
# 15995  106814680   26       1              Среднее  Не состоял в браке
# 15996  106812464   26       0  Среднее специальное      Состою в браке
# 15997  106809255   30       1  Среднее специальное  Не состоял в браке
# 15998  106814593   25       0  Среднее специальное      Состою в браке
# 15999  106813640   26       1               Высшее  Не состоял в браке
#
#        CHILD_TOTAL  DEPENDANTS  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  \
# ...

# %% [markdown]
# ## Join with D_job

# %%
D_job
# Out:
#                     GEN_INDUSTRY                    GEN_TITLE  \
# 0                       Торговля                      Рабочий
# 1                       Торговля                      Рабочий
# 2      Информационные технологии                   Специалист
# 3                    Образование  Руководитель среднего звена
# 4         Государственная служба                   Специалист
# ...                          ...                          ...
# 15218              Строительство                   Специалист
# 15219            Здравоохранение                       Другое
# 15220                   Торговля                     Служащий
# 15221                        NaN                          NaN
# 15222                  Транспорт                   Специалист
#
#                              JOB_DIR  WORK_TIME  ID_CLIENT
# 0        Вспомогательный техперсонал       18.0  106804370
# 1      Участие в основ. деятельности       97.0  106804371
# ...

# %%
D_job.drop_duplicates(subset=["ID_CLIENT"])
# Out:
#                     GEN_INDUSTRY                    GEN_TITLE  \
# 0                       Торговля                      Рабочий
# 1                       Торговля                      Рабочий
# 2      Информационные технологии                   Специалист
# 3                    Образование  Руководитель среднего звена
# 4         Государственная служба                   Специалист
# ...                          ...                          ...
# 15218              Строительство                   Специалист
# 15219            Здравоохранение                       Другое
# 15220                   Торговля                     Служащий
# 15221                        NaN                          NaN
# 15222                  Транспорт                   Специалист
#
#                              JOB_DIR  WORK_TIME  ID_CLIENT
# 0        Вспомогательный техперсонал       18.0  106804370
# 1      Участие в основ. деятельности       97.0  106804371
# ...

# %%
D_job.isna().any()
# Out:
# GEN_INDUSTRY     True
# GEN_TITLE        True
# JOB_DIR          True
# WORK_TIME        True
# ID_CLIENT       False
# dtype: bool

# %%
D_job[D_job["GEN_INDUSTRY"].isna()]
# Out:
#       GEN_INDUSTRY GEN_TITLE JOB_DIR  WORK_TIME  ID_CLIENT
# 16             NaN       NaN     NaN        NaN  106804386
# 29             NaN       NaN     NaN        NaN  106804399
# 40             NaN       NaN     NaN        NaN  106804410
# 43             NaN       NaN     NaN        NaN  106804413
# 53             NaN       NaN     NaN        NaN  106804423
# ...            ...       ...     ...        ...        ...
# 15185          NaN       NaN     NaN        NaN  106819555
# 15191          NaN       NaN     NaN        NaN  106819561
# 15196          NaN       NaN     NaN        NaN  106819566
# 15197          NaN       NaN     NaN        NaN  106819567
# 15221          NaN       NaN     NaN        NaN  106819591
#
# [1367 rows x 5 columns]

# %%
D_job[D_job["GEN_INDUSTRY"].isna()].drop(columns=["ID_CLIENT"]).isna().all()
# Out:
# GEN_INDUSTRY    True
# GEN_TITLE       True
# JOB_DIR         True
# WORK_TIME       True
# dtype: bool

# %% [markdown]
# Есть 1367 клиентов, для которых нет информации о работе.

# %%
df = df.merge(D_job.drop(columns=["ID_CLIENT"]), how="left", left_on="ID", right_on=D_job["ID_CLIENT"])
df
# Out:
#               ID  AGE  GENDER            EDUCATION      MARITAL_STATUS  \
# 0      106805103   42       1              Среднее  Не состоял в браке
# 1      106809308   28       1  Среднее специальное      Состою в браке
# 2      106805867   64       0  Среднее специальное      Состою в браке
# 3      106808779   54       1  Среднее специальное      Состою в браке
# 4      106814289   26       0  Среднее специальное      Состою в браке
# ...          ...  ...     ...                  ...                 ...
# 15218  106814680   26       1              Среднее  Не состоял в браке
# 15219  106812464   26       0  Среднее специальное      Состою в браке
# 15220  106809255   30       1  Среднее специальное  Не состоял в браке
# 15221  106814593   25       0  Среднее специальное      Состою в браке
# 15222  106813640   26       1               Высшее  Не состоял в браке
#
#        CHILD_TOTAL  DEPENDANTS  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  \
# ...

# %%
df[df["SOCSTATUS_WORK_FL"] == 0].isna().all()
# Out:
# ID                           False
# AGE                          False
# GENDER                       False
# EDUCATION                    False
# MARITAL_STATUS               False
# CHILD_TOTAL                  False
# DEPENDANTS                   False
# SOCSTATUS_WORK_FL            False
# SOCSTATUS_PENS_FL            False
# REG_ADDRESS_PROVINCE         False
# FACT_ADDRESS_PROVINCE        False
# POSTAL_ADDRESS_PROVINCE      False
# FL_PRESENCE_FL               False
# OWN_AUTO                     False
# SOCSTATUS_WORK_FL_COMMENT    False
# SOCSTATUS_PENS_FL_COMMENT    False
# AGREEMENT_RK                 False
# TARGET                       False
# GEN_INDUSTRY                 False
# GEN_TITLE                    False
# JOB_DIR                      False
# WORK_TIME                    False
# dtype: bool

# %% [markdown]
# Есть неработающие лица, для которых была информация о работе. Почистим.

# %%
df[(df["SOCSTATUS_WORK_FL"] == 0) & (~df["GEN_INDUSTRY"].isna())]
# Out:
#               ID  AGE  GENDER            EDUCATION      MARITAL_STATUS  \
# 526    106812580   55       1               Высшее      Состою в браке
# 2784   106804382   62       0              Среднее    Гражданский брак
# 4273   106817885   50       1              Среднее      Состою в браке
# 5337   106812288   62       1  Среднее специальное      Состою в браке
# 6016   106815969   44       1              Среднее  Не состоял в браке
# 6910   106810137   52       1              Среднее      Состою в браке
# 7047   106814217   55       1              Среднее      Состою в браке
# 11054  106814375   65       1     Неполное среднее        Вдовец/Вдова
# 11099  106816459   51       0     Неполное среднее      Состою в браке
# 11735  106817239   54       1              Среднее  Не состоял в браке
#
#        CHILD_TOTAL  DEPENDANTS  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  \
# 526              3           0                  0                  1
# ...

# %% [markdown]
# Они все пенсионеры, поэтому, вероятно, информация о работе старая.

# %%
import numpy as np
df.loc[(df["SOCSTATUS_WORK_FL"] == 0) & (~df["GEN_INDUSTRY"].isna()), ["GEN_INDUSTRY", "GEN_TITLE", "JOB_DIR", "WORK_TIME"]] = np.nan

# %%
df[(df["SOCSTATUS_WORK_FL"] != 0) & (df["GEN_INDUSTRY"].isna())]
# Out:
#              ID  AGE  GENDER            EDUCATION      MARITAL_STATUS  \
# 4904  106812333   24       0  Среднее специальное  Не состоял в браке
#
#       CHILD_TOTAL  DEPENDANTS  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  \
# 4904            0           0                  1                  0
#
#      REG_ADDRESS_PROVINCE  ... FL_PRESENCE_FL OWN_AUTO  \
# 4904      Курская область  ...              0        0
#
#       SOCSTATUS_WORK_FL_COMMENT  SOCSTATUS_PENS_FL_COMMENT AGREEMENT_RK  \
# 4904                   работает               не пенсионер     64469089
#
#      TARGET  GEN_INDUSTRY  GEN_TITLE JOB_DIR WORK_TIME
# 4904      0           NaN        NaN     NaN       NaN
#
# [1 rows x 22 columns]

# %% [markdown]
# Есть человек, который якобы работает, но информации по его работе нет. Наверное, он все же не работает.

# %%
df.loc[(df["SOCSTATUS_WORK_FL"] != 0) & (df["GEN_INDUSTRY"].isna()), "SOCSTATUS_WORK_FL_COMMENT"] = "не работает"
df.loc[(df["SOCSTATUS_WORK_FL"] != 0) & (df["GEN_INDUSTRY"].isna()), "SOCSTATUS_WORK_FL"] = 0

# %%
df[df["SOCSTATUS_WORK_FL"] != 0].isna().any()
# Out:
# ID                           False
# AGE                          False
# GENDER                       False
# EDUCATION                    False
# MARITAL_STATUS               False
# CHILD_TOTAL                  False
# DEPENDANTS                   False
# SOCSTATUS_WORK_FL            False
# SOCSTATUS_PENS_FL            False
# REG_ADDRESS_PROVINCE         False
# FACT_ADDRESS_PROVINCE        False
# POSTAL_ADDRESS_PROVINCE      False
# FL_PRESENCE_FL               False
# OWN_AUTO                     False
# SOCSTATUS_WORK_FL_COMMENT    False
# SOCSTATUS_PENS_FL_COMMENT    False
# AGREEMENT_RK                 False
# TARGET                       False
# GEN_INDUSTRY                 False
# GEN_TITLE                    False
# JOB_DIR                      False
# WORK_TIME                    False
# dtype: bool

# %%
df[df["SOCSTATUS_WORK_FL"] == 0].isna().all()
# Out:
# ID                           False
# AGE                          False
# GENDER                       False
# EDUCATION                    False
# MARITAL_STATUS               False
# CHILD_TOTAL                  False
# DEPENDANTS                   False
# SOCSTATUS_WORK_FL            False
# SOCSTATUS_PENS_FL            False
# REG_ADDRESS_PROVINCE         False
# FACT_ADDRESS_PROVINCE        False
# POSTAL_ADDRESS_PROVINCE      False
# FL_PRESENCE_FL               False
# OWN_AUTO                     False
# SOCSTATUS_WORK_FL_COMMENT    False
# SOCSTATUS_PENS_FL_COMMENT    False
# AGREEMENT_RK                 False
# TARGET                       False
# GEN_INDUSTRY                  True
# GEN_TITLE                     True
# JOB_DIR                       True
# WORK_TIME                     True
# dtype: bool

# %% [markdown]
# ## Join with D_salary

# %%
D_salary
# Out:
#                 FAMILY_INCOME  PERSONAL_INCOME  ID_CLIENT
# 0      от 20000 до 50000 руб.          20000.0  106809321
# 1      от 20000 до 50000 руб.          14000.0  106815561
# 2      от 10000 до 20000 руб.          15000.0  106811521
# 3      от 20000 до 50000 руб.          20000.0  106811252
# 4      от 20000 до 50000 руб.          25000.0  106808620
# ...                       ...              ...        ...
# 15518  от 20000 до 50000 руб.          15000.0  106812538
# 15519  от 10000 до 20000 руб.          12000.0  106814158
# 15520  от 10000 до 20000 руб.          14000.0  106805134
# 15521  от 10000 до 20000 руб.           7000.0  106812867
# 15522   от 5000 до 10000 руб.           5200.0  106808024
#
# [15523 rows x 3 columns]

# %%
D_salary.describe()
# Out:
#        PERSONAL_INCOME     ID_CLIENT
# count     15523.000000  1.552300e+04
# mean      13848.041638  1.068120e+08
# std        8998.618992  4.395857e+03
# min          24.000000  1.068044e+08
# 25%        8000.000000  1.068082e+08
# 50%       12000.000000  1.068120e+08
# 75%       17000.000000  1.068158e+08
# max      250000.000000  1.068196e+08

# %%
D_salary.isna().any()
# Out:
# FAMILY_INCOME      False
# PERSONAL_INCOME    False
# ID_CLIENT          False
# dtype: bool

# %%
df = df.merge(D_salary.drop(columns=["ID_CLIENT"]), how="left", left_on="ID", right_on=D_salary["ID_CLIENT"])
df
# Out:
#               ID  AGE  GENDER            EDUCATION      MARITAL_STATUS  \
# 0      106805103   42       1              Среднее  Не состоял в браке
# 1      106809308   28       1  Среднее специальное      Состою в браке
# 2      106805867   64       0  Среднее специальное      Состою в браке
# 3      106808779   54       1  Среднее специальное      Состою в браке
# 4      106814289   26       0  Среднее специальное      Состою в браке
# ...          ...  ...     ...                  ...                 ...
# 15518  106814680   26       1              Среднее  Не состоял в браке
# 15519  106812464   26       0  Среднее специальное      Состою в браке
# 15520  106809255   30       1  Среднее специальное  Не состоял в браке
# 15521  106814593   25       0  Среднее специальное      Состою в браке
# 15522  106813640   26       1               Высшее  Не состоял в браке
#
#        CHILD_TOTAL  DEPENDANTS  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  \
# ...

# %%
df.isna().any()
# Out:
# ID                           False
# AGE                          False
# GENDER                       False
# EDUCATION                    False
# MARITAL_STATUS               False
# CHILD_TOTAL                  False
# DEPENDANTS                   False
# SOCSTATUS_WORK_FL            False
# SOCSTATUS_PENS_FL            False
# REG_ADDRESS_PROVINCE         False
# FACT_ADDRESS_PROVINCE        False
# POSTAL_ADDRESS_PROVINCE      False
# FL_PRESENCE_FL               False
# OWN_AUTO                     False
# SOCSTATUS_WORK_FL_COMMENT    False
# SOCSTATUS_PENS_FL_COMMENT    False
# AGREEMENT_RK                 False
# TARGET                       False
# GEN_INDUSTRY                  True
# GEN_TITLE                     True
# JOB_DIR                       True
# WORK_TIME                     True
# FAMILY_INCOME                False
# PERSONAL_INCOME              False
# dtype: bool

# %%
df[(df["SOCSTATUS_WORK_FL"] == 0) & (df["PERSONAL_INCOME"] > 0)]
# Out:
#               ID  AGE  GENDER            EDUCATION      MARITAL_STATUS  \
# 5      106814758   63       1              Среднее      Состою в браке
# 14     106809086   52       1  Среднее специальное        Вдовец/Вдова
# 17     106810469   62       1     Неполное среднее  Не состоял в браке
# 20     106806814   64       0               Высшее  Не состоял в браке
# 28     106810992   58       0              Среднее      Состою в браке
# ...          ...  ...     ...                  ...                 ...
# 15487  106816230   61       1  Среднее специальное      Состою в браке
# 15496  106819503   62       1  Среднее специальное      Состою в браке
# 15513  106810975   62       1  Среднее специальное        Вдовец/Вдова
# 15515  106813784   64       1              Среднее        Вдовец/Вдова
# 15517  106807566   63       0              Среднее      Состою в браке
#
#        CHILD_TOTAL  DEPENDANTS  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  \
# ...

# %%
df[(df["SOCSTATUS_WORK_FL"] == 0) & (df["PERSONAL_INCOME"] > 0)]["SOCSTATUS_PENS_FL"].value_counts()
# Out:
# 1    1407
# 0       1
# Name: SOCSTATUS_PENS_FL, dtype: int64

# %% [markdown]
# Есть один человек, который получает какую-то зарплату, не работает и не является пенсионером. Посмотрим.

# %%
df[(df["SOCSTATUS_WORK_FL"] == 0) & (df["PERSONAL_INCOME"] > 0) & (df["SOCSTATUS_PENS_FL"] == 0)]
# Out:
#              ID  AGE  GENDER            EDUCATION      MARITAL_STATUS  \
# 5005  106812333   24       0  Среднее специальное  Не состоял в браке
#
#       CHILD_TOTAL  DEPENDANTS  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  \
# 5005            0           0                  0                  0
#
#      REG_ADDRESS_PROVINCE  ... SOCSTATUS_WORK_FL_COMMENT  \
# 5005      Курская область  ...               не работает
#
#      SOCSTATUS_PENS_FL_COMMENT  AGREEMENT_RK  TARGET GEN_INDUSTRY GEN_TITLE  \
# 5005              не пенсионер      64469089       0          NaN       NaN
#
#       JOB_DIR  WORK_TIME           FAMILY_INCOME PERSONAL_INCOME
# 5005      NaN        NaN  от 10000 до 20000 руб.         10000.0
#
# [1 rows x 24 columns]

# %% [markdown]
# Это был как раз тот человек, который не имел информации о работе выше. Давайте вообще дропнем его, непонятно, что с ним делать.

# %%
df = df[df["ID"] != 106812333]

# %% [markdown]
# ## Получение LOAN_NUM_TOTAL и LOAN_NUM_CLOSED

# %%
D_loan
# Out:
#           ID_LOAN  ID_CLIENT
# 0      1753790658  106804370
# 1      1753790659  106804371
# 2      1753790660  106804372
# 3      1753790661  106804372
# 4      1753790662  106804373
# ...           ...        ...
# 21121  1753811779  106819588
# 21122  1753811780  106819589
# 21123  1753811781  106819590
# 21124  1753811782  106819591
# 21125  1753811783  106819592
#
# [21126 rows x 2 columns]

# %%
D_loan.drop_duplicates()
# Out:
#           ID_LOAN  ID_CLIENT
# 0      1753790658  106804370
# 1      1753790659  106804371
# 2      1753790660  106804372
# 3      1753790661  106804372
# 4      1753790662  106804373
# ...           ...        ...
# 21121  1753811779  106819588
# 21122  1753811780  106819589
# 21123  1753811781  106819590
# 21124  1753811782  106819591
# 21125  1753811783  106819592
#
# [21126 rows x 2 columns]

# %%
D_loan.isna().any()
# Out:
# ID_LOAN      False
# ID_CLIENT    False
# dtype: bool

# %%
D_close_loan
# Out:
#           ID_LOAN  CLOSED_FL
# 0      1753790658          1
# 1      1753790659          1
# 2      1753790660          1
# 3      1753790661          0
# 4      1753790662          1
# ...           ...        ...
# 21121  1753811779          1
# 21122  1753811780          0
# 21123  1753811781          0
# 21124  1753811782          0
# 21125  1753811783          0
#
# [21126 rows x 2 columns]

# %%
D_close_loan.drop_duplicates("ID_LOAN")
# Out:
#           ID_LOAN  CLOSED_FL
# 0      1753790658          1
# 1      1753790659          1
# 2      1753790660          1
# 3      1753790661          0
# 4      1753790662          1
# ...           ...        ...
# 21121  1753811779          1
# 21122  1753811780          0
# 21123  1753811781          0
# 21124  1753811782          0
# 21125  1753811783          0
#
# [21126 rows x 2 columns]

# %%
D_close_loan.isna().any()
# Out:
# ID_LOAN      False
# CLOSED_FL    False
# dtype: bool

# %%
D_close_loan.describe()
# Out:
#             ID_LOAN     CLOSED_FL
# count  2.112600e+04  21126.000000
# mean   1.753801e+09      0.541797
# std    6.098695e+03      0.498262
# min    1.753791e+09      0.000000
# 25%    1.753796e+09      0.000000
# 50%    1.753801e+09      1.000000
# 75%    1.753807e+09      1.000000
# max    1.753812e+09      1.000000

# %%
total_client_loans = D_loan.groupby("ID_CLIENT").count().reset_index()
total_client_loans
# Out:
#        ID_CLIENT  ID_LOAN
# 0      106804370        1
# 1      106804371        1
# 2      106804372        2
# 3      106804373        1
# 4      106804374        2
# ...          ...      ...
# 15218  106819588        3
# 15219  106819589        1
# 15220  106819590        1
# 15221  106819591        1
# 15222  106819592        1
#
# [15223 rows x 2 columns]

# %%
df = df.merge(total_client_loans["ID_LOAN"].rename("LOAN_NUM_TOTAL"), left_on="ID", right_on=total_client_loans["ID_CLIENT"])
df
# Out:
#               ID  AGE  GENDER            EDUCATION      MARITAL_STATUS  \
# 0      106805103   42       1              Среднее  Не состоял в браке
# 1      106809308   28       1  Среднее специальное      Состою в браке
# 2      106805867   64       0  Среднее специальное      Состою в браке
# 3      106808779   54       1  Среднее специальное      Состою в браке
# 4      106814289   26       0  Среднее специальное      Состою в браке
# ...          ...  ...     ...                  ...                 ...
# 15517  106814680   26       1              Среднее  Не состоял в браке
# 15518  106812464   26       0  Среднее специальное      Состою в браке
# 15519  106809255   30       1  Среднее специальное  Не состоял в браке
# 15520  106814593   25       0  Среднее специальное      Состою в браке
# 15521  106813640   26       1               Высшее  Не состоял в браке
#
#        CHILD_TOTAL  DEPENDANTS  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  \
# ...

# %%
df["LOAN_NUM_TOTAL"].value_counts()
# Out:
# 1     11517
# 2      2680
# 3       885
# 4       280
# 5       105
# 6        36
# 7        14
# 8         4
# 11        1
# Name: LOAN_NUM_TOTAL, dtype: int64

# %%
closed_loans = D_loan.merge(D_close_loan, on="ID_LOAN").groupby("ID_CLIENT").count().drop(columns=["ID_LOAN"]).reset_index()
closed_loans
# Out:
#        ID_CLIENT  CLOSED_FL
# 0      106804370          1
# 1      106804371          1
# 2      106804372          2
# 3      106804373          1
# 4      106804374          2
# ...          ...        ...
# 15218  106819588          3
# 15219  106819589          1
# 15220  106819590          1
# 15221  106819591          1
# 15222  106819592          1
#
# [15223 rows x 2 columns]

# %%
df = df.merge(closed_loans["CLOSED_FL"].rename("LOAN_NUM_CLOSED"), left_on="ID", right_on=closed_loans["ID_CLIENT"])
df
# Out:
#               ID  AGE  GENDER            EDUCATION      MARITAL_STATUS  \
# 0      106805103   42       1              Среднее  Не состоял в браке
# 1      106809308   28       1  Среднее специальное      Состою в браке
# 2      106805867   64       0  Среднее специальное      Состою в браке
# 3      106808779   54       1  Среднее специальное      Состою в браке
# 4      106814289   26       0  Среднее специальное      Состою в браке
# ...          ...  ...     ...                  ...                 ...
# 15517  106814680   26       1              Среднее  Не состоял в браке
# 15518  106812464   26       0  Среднее специальное      Состою в браке
# 15519  106809255   30       1  Среднее специальное  Не состоял в браке
# 15520  106814593   25       0  Среднее специальное      Состою в браке
# 15521  106813640   26       1               Высшее  Не состоял в браке
#
#        CHILD_TOTAL  DEPENDANTS  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  \
# ...

# %%
df.isna().any()
# Out:
# ID                           False
# AGE                          False
# GENDER                       False
# EDUCATION                    False
# MARITAL_STATUS               False
# CHILD_TOTAL                  False
# DEPENDANTS                   False
# SOCSTATUS_WORK_FL            False
# SOCSTATUS_PENS_FL            False
# REG_ADDRESS_PROVINCE         False
# FACT_ADDRESS_PROVINCE        False
# POSTAL_ADDRESS_PROVINCE      False
# FL_PRESENCE_FL               False
# OWN_AUTO                     False
# SOCSTATUS_WORK_FL_COMMENT    False
# SOCSTATUS_PENS_FL_COMMENT    False
# AGREEMENT_RK                 False
# TARGET                       False
# GEN_INDUSTRY                  True
# GEN_TITLE                     True
# JOB_DIR                       True
# WORK_TIME                     True
# FAMILY_INCOME                False
# PERSONAL_INCOME              False
# LOAN_NUM_TOTAL               False
# LOAN_NUM_CLOSED              False
# dtype: bool

# %%
df[df["LOAN_NUM_TOTAL"] < df["LOAN_NUM_CLOSED"]]
# Out:
# Empty DataFrame
# Columns: [ID, AGE, GENDER, EDUCATION, MARITAL_STATUS, CHILD_TOTAL, DEPENDANTS, SOCSTATUS_WORK_FL, SOCSTATUS_PENS_FL, REG_ADDRESS_PROVINCE, FACT_ADDRESS_PROVINCE, POSTAL_ADDRESS_PROVINCE, FL_PRESENCE_FL, OWN_AUTO, SOCSTATUS_WORK_FL_COMMENT, SOCSTATUS_PENS_FL_COMMENT, AGREEMENT_RK, TARGET, GEN_INDUSTRY, GEN_TITLE, JOB_DIR, WORK_TIME, FAMILY_INCOME, PERSONAL_INCOME, LOAN_NUM_TOTAL, LOAN_NUM_CLOSED]
# Index: []
#
# [0 rows x 26 columns]

# %%
df[["LOAN_NUM_TOTAL", "LOAN_NUM_CLOSED"]].describe()
# Out:
#        LOAN_NUM_TOTAL  LOAN_NUM_CLOSED
# count    15522.000000     15522.000000
# mean         1.387321         1.387321
# std          0.794261         0.794261
# min          1.000000         1.000000
# 25%          1.000000         1.000000
# 50%          1.000000         1.000000
# 75%          2.000000         2.000000
# max         11.000000        11.000000

# %% [markdown]
# **D_clients**
#
# Описание данных клиентов:
# - ID — идентификатор записи;
# - AGE	— возраст клиента;
# - GENDER — пол клиента (1 — мужчина, 0 — женщина);
# - EDUCATION — образование;
# - MARITAL_STATUS — семейное положение;
# - CHILD_TOTAL	— количество детей клиента;
# - DEPENDANTS — количество иждивенцев клиента;
# - SOCSTATUS_WORK_FL	— социальный статус клиента относительно работы (1 — работает, 0 — не работает);
# - SOCSTATUS_PENS_FL	— социальный статус клиента относительно пенсии (1 — пенсионер, 0 — не пенсионер);
# - REG_ADDRESS_PROVINCE — область регистрации клиента;
# - FACT_ADDRESS_PROVINCE — область фактического пребывания клиента;
# - POSTAL_ADDRESS_PROVINCE — почтовый адрес области;
# - FL_PRESENCE_FL — наличие в собственности квартиры (1 — есть, 0 — нет);
# - OWN_AUTO — количество автомобилей в собственности.
#
#
# **D_last_credit**
#
# Информация о последнем займе клиента:
# - ID_CLIENT — идентификатор клиента;
# - CREDIT — сумма последнего кредита клиента (в рублях);
# - TERM — срок кредита;
# - FST_PAYMENT — первоначальный взнос (в рублях).
#
#
# **D_loan**
#
# Информация о кредитной истории клиента:
# - ID_CLIENT — идентификатор клиента;
# - ID_LOAN — идентификатор кредита.
#
# **D_close_loan**
#
# Информация о статусах кредита (ссуд):
# - ID_LOAN — идентификатор кредита;
# - CLOSED_FL — текущий статус кредита (1 — закрыт, 0 — не закрыт).

# %%
df.columns
# Out:
# Index(['ID', 'AGE', 'GENDER', 'EDUCATION', 'MARITAL_STATUS', 'CHILD_TOTAL',
#        'DEPENDANTS', 'SOCSTATUS_WORK_FL', 'SOCSTATUS_PENS_FL',
#        'REG_ADDRESS_PROVINCE', 'FACT_ADDRESS_PROVINCE',
#        'POSTAL_ADDRESS_PROVINCE', 'FL_PRESENCE_FL', 'OWN_AUTO',
#        'SOCSTATUS_WORK_FL_COMMENT', 'SOCSTATUS_PENS_FL_COMMENT',
#        'AGREEMENT_RK', 'TARGET', 'GEN_INDUSTRY', 'GEN_TITLE', 'JOB_DIR',
#        'WORK_TIME', 'FAMILY_INCOME', 'PERSONAL_INCOME', 'LOAN_NUM_TOTAL',
#        'LOAN_NUM_CLOSED'],
#       dtype='object')

# %% [markdown]
# ## Последняя проверка и чистка

# %%
df = df.drop_duplicates(["ID"])
df
# Out:
#               ID  AGE  GENDER            EDUCATION      MARITAL_STATUS  \
# 0      106805103   42       1              Среднее  Не состоял в браке
# 1      106809308   28       1  Среднее специальное      Состою в браке
# 2      106805867   64       0  Среднее специальное      Состою в браке
# 3      106808779   54       1  Среднее специальное      Состою в браке
# 4      106814289   26       0  Среднее специальное      Состою в браке
# ...          ...  ...     ...                  ...                 ...
# 15517  106814680   26       1              Среднее  Не состоял в браке
# 15518  106812464   26       0  Среднее специальное      Состою в браке
# 15519  106809255   30       1  Среднее специальное  Не состоял в браке
# 15520  106814593   25       0  Среднее специальное      Состою в браке
# 15521  106813640   26       1               Высшее  Не состоял в браке
#
#        CHILD_TOTAL  DEPENDANTS  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  \
# ...

# %%
df.drop_duplicates(["AGREEMENT_RK"])
# Out:
#               ID  AGE  GENDER            EDUCATION      MARITAL_STATUS  \
# 0      106805103   42       1              Среднее  Не состоял в браке
# 1      106809308   28       1  Среднее специальное      Состою в браке
# 2      106805867   64       0  Среднее специальное      Состою в браке
# 3      106808779   54       1  Среднее специальное      Состою в браке
# 4      106814289   26       0  Среднее специальное      Состою в браке
# ...          ...  ...     ...                  ...                 ...
# 15517  106814680   26       1              Среднее  Не состоял в браке
# 15518  106812464   26       0  Среднее специальное      Состою в браке
# 15519  106809255   30       1  Среднее специальное  Не состоял в браке
# 15520  106814593   25       0  Среднее специальное      Состою в браке
# 15521  106813640   26       1               Высшее  Не состоял в браке
#
#        CHILD_TOTAL  DEPENDANTS  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  \
# ...

# %%
len(D_clients) - len(df), (len(D_clients) - len(df)) / len(D_clients)
# Out:
# (778, 0.048625)

# %% [markdown]
# Всего мы дропнули 778 пользователей из 16000, где-то 5%.

# %%
df.to_csv("clean.csv", index=False)
